# %% [markdown]
# # IPhO 1998 - Rolling Hexagon

# %% [markdown]
# Шестиугольная призма катится по наклонной плоскости без проскальзывания.

# %% [markdown]
# a) В процессе качения призма по очереди вращается вокруг 6 ребер. Ось меняется в момент когда следующее ребро касается поверхности.
# Пусть $\omega_i$ - угловая скорость призмы до смены оси, $\omega_f$ - после

# %% [markdown]
# __Покажите, что можно записать__:
# $\omega_f = s\omega_i$
#
# __и найдите коэффициент__ $\textbf{s}$

# %% [markdown]
# ![image.png](attachment:image.png)
